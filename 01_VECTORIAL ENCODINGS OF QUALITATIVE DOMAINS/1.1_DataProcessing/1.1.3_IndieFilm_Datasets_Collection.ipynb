# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyCunsiTfGCaIJiyZgRpnXtZEaRKUujn7ps'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_popular_videos(channel_id):
    videos = []
    next_page_token = None

    while True:
        res = youtube.search().list(
            part="snippet",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token,
            order="viewCount"
        ).execute()

        for item in res['items']:
            if item['id']['kind'] == "youtube#video":
                video_id = item['id']['videoId']
                video_title = item['snippet']['title']
                video_url = f"https://www.youtube.com/watch?v={video_id}"
                videos.append((video_title, video_url))

        next_page_token = res.get('nextPageToken')
        if not next_page_token:
            break

    return videos

channel_id = 'UCyp-EzJrdTOd9uNPvmdst-w'
videos = get_popular_videos(channel_id)
for title, url in videos:
    print(url)
# Out:
# https://www.youtube.com/watch?v=hnKrUB5HAiM
# https://www.youtube.com/watch?v=Ev2g6U30XU0
# https://www.youtube.com/watch?v=WC9uSdkJS6U
# https://www.youtube.com/watch?v=RaRa5f8fKk8
# https://www.youtube.com/watch?v=ueZdjaapq40
# https://www.youtube.com/watch?v=QSziAReB7ys
# https://www.youtube.com/watch?v=2dD3Fawk4y0
# https://www.youtube.com/watch?v=35i4zTky9pI
# https://www.youtube.com/watch?v=5qKYrajRNwo
# https://www.youtube.com/watch?v=ZCa0saE-fcI
# https://www.youtube.com/watch?v=KI2lsdXJQ40
# https://www.youtube.com/watch?v=bX8GaZ3O4-Q
# https://www.youtube.com/watch?v=h1PjJ9_Yd2c
# https://www.youtube.com/watch?v=mnzcYc58xus
# https://www.youtube.com/watch?v=TGZg1YqXv9o
# https://www.youtube.com/watch?v=Tl83z6m-CJQ
# https://www.youtube.com/watch?v=mXZ45yLpg14
# https://www.youtube.com/watch?v=fHhYjXRKvGs
# https://www.youtube.com/watch?v=BwZDibyV410
# https://www.youtube.com/watch?v=gui8WYigMpg
# https://www.youtube.com/watch?v=KSKjxrL0MWo
# ...

# %%
from pytube import YouTube
import os
import time
import threading
from pytube.exceptions import AgeRestrictedError

video_links = [
    "https://www.youtube.com/watch?v=hnKrUB5HAiM",
    "https://www.youtube.com/watch?v=Ev2g6U30XU0",
    "https://www.youtube.com/watch?v=WC9uSdkJS6U",
    "https://www.youtube.com/watch?v=RaRa5f8fKk8",
    "https://www.youtube.com/watch?v=ueZdjaapq40",
    "https://www.youtube.com/watch?v=QSziAReB7ys",
    "https://www.youtube.com/watch?v=2dD3Fawk4y0",
    "https://www.youtube.com/watch?v=35i4zTky9pI",
    "https://www.youtube.com/watch?v=5qKYrajRNwo",
    "https://www.youtube.com/watch?v=ZCa0saE-fcI",
    "https://www.youtube.com/watch?v=KI2lsdXJQ40",
    "https://www.youtube.com/watch?v=bX8GaZ3O4-Q",
    "https://www.youtube.com/watch?v=h1PjJ9_Yd2c",
    "https://www.youtube.com/watch?v=mnzcYc58xus",
    "https://www.youtube.com/watch?v=TGZg1YqXv9o",
    "https://www.youtube.com/watch?v=Tl83z6m-CJQ",
    "https://www.youtube.com/watch?v=mXZ45yLpg14",
    "https://www.youtube.com/watch?v=fHhYjXRKvGs",
    "https://www.youtube.com/watch?v=BwZDibyV410",
    "https://www.youtube.com/watch?v=gui8WYigMpg",
    "https://www.youtube.com/watch?v=KSKjxrL0MWo",
    "https://www.youtube.com/watch?v=q4Wrew3vSDU",
    "https://www.youtube.com/watch?v=cExhFUuRUNE",
    "https://www.youtube.com/watch?v=ugPJi8kMK8Q",
    "https://www.youtube.com/watch?v=KOwKExagzdQ",
    "https://www.youtube.com/watch?v=NjqT-3TKC3M",
    "https://www.youtube.com/watch?v=c_S9UUHJNaw",
    "https://www.youtube.com/watch?v=xLOStatiX48",
    "https://www.youtube.com/watch?v=CnxYtSKgbgs",
    "https://www.youtube.com/watch?v=OcnsVXmOi78",
    "https://www.youtube.com/watch?v=1MEmiZ5svgk",
    "https://www.youtube.com/watch?v=0hIg5cGRpIA",
    "https://www.youtube.com/watch?v=i8MQl7vCkMQ",
    "https://www.youtube.com/watch?v=aseq2GClZ9U",
    "https://www.youtube.com/watch?v=0yCMjvE566c",
    "https://www.youtube.com/watch?v=ye9GdZ6R-hQ",
    "https://www.youtube.com/watch?v=hkhZ1sFBKDs",
    "https://www.youtube.com/watch?v=Tp4Rs1ng7yI",
    "https://www.youtube.com/watch?v=rKmlbFgpnho",
    "https://www.youtube.com/watch?v=SIdHBJmZWe8",
    "https://www.youtube.com/watch?v=3O9OO5TWY2c",
]

if not os.path.exists(r'D:\Independent_Films'):
    os.makedirs(r'D:\Independent_Films')

def download_with_timeout(link):
    try:
        yt = YouTube(link)
        video_title = yt.title
        print(f"Downloading {video_title}...")
        video = yt.streams.filter(res='720p', file_extension='mp4').first()
        video.download(output_path=r'D:\Independent_Films')
        print(f"{video_title} downloaded successfully!")
    except AgeRestrictedError:
        print(f"{link} is age-restricted and cannot be downloaded.")
    except Exception as e:
        print(f"An error occurred while downloading {link}: {e}")

for link in video_links:
    download_thread = threading.Thread(target=download_with_timeout, args=(link,))
    download_thread.start()
    download_thread.join(timeout=40)
    if download_thread.is_alive():
        print(f"Download of {link} timed out. Skipping...")

print("All videos downloaded successfully!")
# Out:
# ...
# https://www.youtube.com/watch?v=hnKrUB5HAiM is age-restricted and cannot be downloaded.
# ...
# https://www.youtube.com/watch?v=Ev2g6U30XU0 is age-restricted and cannot be downloaded.
# ...
# Hot Seat | Sundance Short Film | Teen Party has a Wild Surprise downloaded successfully!
# ...
# Yulia & Juliet | Queer Short Film about Forbidden Love downloaded successfully!
# ...
# Short Film about Weight and Female Empowerment | Bye Bye Body downloaded successfully!
# ...
# https://www.youtube.com/watch?v=QSziAReB7ys is age-restricted and cannot be downloaded.
# ...
# Curve | Disturbing Horror Short Film downloaded successfully!
# ...
# Lost & Found | Oscar Shortlisted Stop-Motion Animation | Short of the Week downloaded successfully!
# ...
# Award-Winning Stop Motion Animated Short | Tokri (The Basket) downloaded successfully!
# ...
# Hold Your Breath | Short Film Drama by Theo Le Sourd downloaded successfully!
# ...
# Negative Space | Oscar Nominated Stop-Motion Animation | Short of the Week downloaded successfully!
# ...

# %%
from pytube import YouTube
import os
import time
import threading
from pytube.exceptions import AgeRestrictedError

video_links = [
    "https://www.youtube.com/watch?v=z4tMdqm84Tk",
    "https://www.youtube.com/watch?v=SvimE7yif2E",
    "https://www.youtube.com/watch?v=vmHSQ9JeEUc",
    "https://www.youtube.com/watch?v=1pvoBu3yYRA",
    "https://www.youtube.com/watch?v=DG4W1oWieoM",
    "https://www.youtube.com/watch?v=0NJois4JMGU",
    "https://www.youtube.com/watch?v=kPkxWRSuRxg",
    "https://www.youtube.com/watch?v=CKAKr-juM8M",
    "https://www.youtube.com/watch?v=R-UNLvY1y5k",
    "https://www.youtube.com/watch?v=-2uIa-XMJC0",
    "https://www.youtube.com/watch?v=RZJcik1ONqc",
    "https://www.youtube.com/watch?v=TrGwHNWhf3I",
    "https://www.youtube.com/watch?v=ej2c013HcrA",
    "https://www.youtube.com/watch?v=L1xbFagkx-8",
    "https://www.youtube.com/watch?v=nmmfi9rIIK4",
    "https://www.youtube.com/watch?v=iUPR-xEifFw",
    "https://www.youtube.com/watch?v=rDIhk-uEImg",
    "https://www.youtube.com/watch?v=NDabz80-w8c",
    "https://www.youtube.com/watch?v=l4jxYGndksY",
    "https://www.youtube.com/watch?v=der7Gxyyuqo",
    "https://www.youtube.com/watch?v=MzdmDdXBEVw",
    "https://www.youtube.com/watch?v=23i6ePHpZ0s",
    "https://www.youtube.com/watch?v=wLS_JmpL_70",
    "https://www.youtube.com/watch?v=db0zlcHqstQ",
    "https://www.youtube.com/watch?v=KFtymlqOG5I",
    "https://www.youtube.com/watch?v=Ja2cbT0-qlQ",
    "https://www.youtube.com/watch?v=zlBR90hzYEc",
    "https://www.youtube.com/watch?v=TNtpdvfbTjA",
    "https://www.youtube.com/watch?v=ZJFUrRMGIZ0",
    "https://www.youtube.com/watch?v=f_QTGeHT8Y4",
    "https://www.youtube.com/watch?v=JTLBnjWbpBo",
    "https://www.youtube.com/watch?v=_M0KWbISLTA",
    "https://www.youtube.com/watch?v=7vTqm2zSXPM",
    "https://www.youtube.com/watch?v=hbDhDflF6LE",
    "https://www.youtube.com/watch?v=7hgzkLGFLe8",
    "https://www.youtube.com/watch?v=AIpPiyk7gfo",
    "https://www.youtube.com/watch?v=GfNUC9aDYCg",
    "https://www.youtube.com/watch?v=QONA7q9Je7M",
    "https://www.youtube.com/watch?v=p9hdXUxxuCk",
    "https://www.youtube.com/watch?v=Oc-lKTEkihc",
    "https://www.youtube.com/watch?v=paiVZ93ZroU",
    "https://www.youtube.com/watch?v=Lq1apxTurPU",
    "https://www.youtube.com/watch?v=1VAYe3Eqst8",
    "https://www.youtube.com/watch?v=8--ssYxXjvQ",
    "https://www.youtube.com/watch?v=plaBtwJm0iQ",
    "https://www.youtube.com/watch?v=FQgpw9pp-qQ",
    "https://www.youtube.com/watch?v=QNFUWAg4qQM",
    "https://www.youtube.com/watch?v=53ZzEviIx_o",
    "https://www.youtube.com/watch?v=qwMe-Z87OZ0",
    "https://www.youtube.com/watch?v=9orX1qpBgN4",
    "https://www.youtube.com/watch?v=fQQCzvko8lg",
    "https://www.youtube.com/watch?v=Z0p72xqbYBE",
    "https://www.youtube.com/watch?v=VuVKX-x9ABM",
    "https://www.youtube.com/watch?v=tDxeduxNE18",
    "https://www.youtube.com/watch?v=kl01fBeh5m4",
    "https://www.youtube.com/watch?v=4Phh2D_ilPE",
    "https://www.youtube.com/watch?v=H5jws8U06VM",
    "https://www.youtube.com/watch?v=87C_A2Apz58",
    "https://www.youtube.com/watch?v=FLOYmmFAsYI",
    "https://www.youtube.com/watch?v=AmlfILu1eO8",
    "https://www.youtube.com/watch?v=4nU_QcjVu9A",
    "https://www.youtube.com/watch?v=GEKCY8VZSb0",
    "https://www.youtube.com/watch?v=kFVOoUZB9XA",
    "https://www.youtube.com/watch?v=tCqgu8JDgA4",
    "https://www.youtube.com/watch?v=gCmmKUyeNBQ",
    "https://www.youtube.com/watch?v=wfwIUak1LGg",
    "https://www.youtube.com/watch?v=Xp5r4yZ-q58",
    "https://www.youtube.com/watch?v=2xIHVrTc0ps",
    "https://www.youtube.com/watch?v=aqc3jFT70BI",
    "https://www.youtube.com/watch?v=ZNT5WM9H_M8",
    "https://www.youtube.com/watch?v=pS47EXccx3I",
    "https://www.youtube.com/watch?v=gmDeljwzlV8",
    "https://www.youtube.com/watch?v=ImnbMyEkXX0",
    "https://www.youtube.com/watch?v=oCEMXhfYA-o",
]

if not os.path.exists(r'D:\Independent_Films'):
    os.makedirs(r'D:\Independent_Films')

def download_with_timeout(link):
    try:
        yt = YouTube(link)
        video_title = yt.title
        print(f"Downloading {video_title}...")
        video = yt.streams.filter(res='720p', file_extension='mp4').first()
        video.download(output_path=r'D:\Independent_Films')
        print(f"{video_title} downloaded successfully!")
    except AgeRestrictedError:
        print(f"{link} is age-restricted and cannot be downloaded.")
    except Exception as e:
        print(f"An error occurred while downloading {link}: {e}")

for link in video_links:
    download_thread = threading.Thread(target=download_with_timeout, args=(link,))
    download_thread.start()
    download_thread.join(timeout=40)
    if download_thread.is_alive():
        print(f"Download of {link} timed out. Skipping...")

print("All videos downloaded successfully!")
# Out:
# ...
# https://www.youtube.com/watch?v=z4tMdqm84Tk is age-restricted and cannot be downloaded.
# ...
# https://www.youtube.com/watch?v=SvimE7yif2E is age-restricted and cannot be downloaded.
# ...
# Good Intentions | Award-Winning Stop-Motion Animated Short Film downloaded successfully!
# ...
# https://www.youtube.com/watch?v=1pvoBu3yYRA is age-restricted and cannot be downloaded.
# ...
# https://www.youtube.com/watch?v=DG4W1oWieoM is age-restricted and cannot be downloaded.
# ...
# INCEL | Drama Short Film by John Merizalde | Short of the Week downloaded successfully!
# ...
# https://www.youtube.com/watch?v=kPkxWRSuRxg is age-restricted and cannot be downloaded.
# ...
# Earthworm | An Unsettling Short Film about the Mundane Horrors of Abortion downloaded successfully!
# ...
# Second Team | Queer Comedy Short Film w/ Francia Raisa and Danielle Savre downloaded successfully!
# ...
# FLITE | Hyper Realistic CG Sci-Fi Short Using Unreal Engine downloaded successfully!
# ...
# The Disappearance of Willie Bingham downloaded successfully!
# ...

# %%
from pytube import YouTube
import os
import time
import threading
from pytube.exceptions import AgeRestrictedError

video_links = [
    "https://www.youtube.com/watch?v=tf12Gx6Za30",
    "https://www.youtube.com/watch?v=JO1lriCv6kI",
    "https://www.youtube.com/watch?v=xOOGhf9zeHA",
    "https://www.youtube.com/watch?v=T1fWZocaqJE",
    "https://www.youtube.com/watch?v=0ID2llvcZMo",
    "https://www.youtube.com/watch?v=B1wTKw2tM4o",
    "https://www.youtube.com/watch?v=_uPn1-ULwg0",
    "https://www.youtube.com/watch?v=6mAydAMKBFM",
    "https://www.youtube.com/watch?v=EeHRw4eGE2c",
    "https://www.youtube.com/watch?v=B7nEYtgz6vk",
    "https://www.youtube.com/watch?v=vD9xcukR-jE",
    "https://www.youtube.com/watch?v=yRR-0IcKLd8",
    "https://www.youtube.com/watch?v=gOyaYdlwUxY",
    "https://www.youtube.com/watch?v=J_EpyxQh00I",
    "https://www.youtube.com/watch?v=J-9MoVlHIE8",
    "https://www.youtube.com/watch?v=yKHjA7oooPE",
    "https://www.youtube.com/watch?v=Hzkd8uTx5w4",
    "https://www.youtube.com/watch?v=MwpObDMo3cM",
    "https://www.youtube.com/watch?v=B2U9KlfUOow",
    "https://www.youtube.com/watch?v=sdrREWvIH3A",
    "https://www.youtube.com/watch?v=c8dGT5PKQaM",
    "https://www.youtube.com/watch?v=fuxVFJb3P-s",
    "https://www.youtube.com/watch?v=l5weL1-KDxY",
    "https://www.youtube.com/watch?v=dhMEBKy3XGw",
    "https://www.youtube.com/watch?v=KQLZploj2KU",
    "https://www.youtube.com/watch?v=s_z4Cbe3VjE",
    "https://www.youtube.com/watch?v=_Y2eqOsdAqY",
    "https://www.youtube.com/watch?v=WeKSMPQ7r3g",
    "https://www.youtube.com/watch?v=_TC-ZcxtaCk",
    "https://www.youtube.com/watch?v=W7itWOILlSw",
    "https://www.youtube.com/watch?v=R9toHYGNqdY",
    "https://www.youtube.com/watch?v=3c9WMJ3nssc",
    "https://www.youtube.com/watch?v=ukuR9FumVYU",
    "https://www.youtube.com/watch?v=MBi7O9IaiEc",
    "https://www.youtube.com/watch?v=46jo7hwHeZ0",
    "https://www.youtube.com/watch?v=7IVOMLKt-jo",
    "https://www.youtube.com/watch?v=I1AOmOw_jEs",
    "https://www.youtube.com/watch?v=Rnc4iwFOJII",
    "https://www.youtube.com/watch?v=2E5XRT8TGVY",
    "https://www.youtube.com/watch?v=9qfjJn33beE",
    "https://www.youtube.com/watch?v=Y1qiXS8qMrA",
    "https://www.youtube.com/watch?v=S4UiZYW3jfI",
    "https://www.youtube.com/watch?v=sv_-rKfdwnc",
    "https://www.youtube.com/watch?v=F_j7wcsvBmM",
    "https://www.youtube.com/watch?v=AxUq-mTh2qM",
    "https://www.youtube.com/watch?v=BcKhkuZi0yo",
    "https://www.youtube.com/watch?v=eQeySVFwGrM",
]

if not os.path.exists(r'D:\Independent_Films'):
    os.makedirs(r'D:\Independent_Films')

def download_with_timeout(link):
    try:
        yt = YouTube(link)
        video_title = yt.title
        print(f"Downloading {video_title}...")
        video = yt.streams.filter(res='720p', file_extension='mp4').first()
        video.download(output_path=r'D:\Independent_Films')
        print(f"{video_title} downloaded successfully!")
    except AgeRestrictedError:
        print(f"{link} is age-restricted and cannot be downloaded.")
    except Exception as e:
        print(f"An error occurred while downloading {link}: {e}")

for link in video_links:
    download_thread = threading.Thread(target=download_with_timeout, args=(link,))
    download_thread.start()
    download_thread.join(timeout=40)
    if download_thread.is_alive():
        print(f"Download of {link} timed out. Skipping...")

print("All videos downloaded successfully!")
# Out:
# ...
# CONTACT - An Animation About Connection in Space by Katy Wang downloaded successfully!
# ...
# F*ck | Comedy Short Film about Parenting starring Brett Goldstein (Ted Lasso) downloaded successfully!
# ...
# https://www.youtube.com/watch?v=xOOGhf9zeHA is age-restricted and cannot be downloaded.
# ...
# Fear Of Flying | Stop Motion Animated Short Film downloaded successfully!
# ...
# LOOP | Sci-Fi Short Film about Artificial Intelligence downloaded successfully!
# ...
# V | Horror Short Film about a Teenage Vampire downloaded successfully!
# ...
# Lovestreams | Short film about how we used to find love on AOL downloaded successfully!
# ...
# My Eyes Are Up Here | Short Film About a Disabled Woman on a Mission To Get the Morning After Pill downloaded successfully!
# ...
# Girls Unlock Door to World of the Dead | Knock Knock Horror Short downloaded successfully!
# ...
# Tribes | Dark Satire Short Film about Identity and Race downloaded successfully!
# ...
# https://www.youtube.com/watch?v=vD9xcukR-jE is age-restricted and cannot be downloaded.
# ...
